# %%
import os
import sys
import json
import urllib.request
import pandas as pd

client_id = "WCNaG4nLp9_1N5q_TNtb"
client_secret = "VjzIwo4BOe"

emoji = pd.read_csv('emoji.csv')
emoji_dict = {}
for i in range(len(emoji)):
    emoji_dict[emoji['Code'][i]] = emoji['CLDR Short Name'][i]

for text in emoji_dict.values():
    encText = urllib.parse.quote(text)
    data = "source=en&target=ko&text=" + encText
    url = "https://openapi.naver.com/v1/papago/n2mt"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        decode = json.loads(response_body.decode('utf-8'))
        result = decode['message']['result']['translatedText']
        print(result)
    else:
        print("Error Code:" + rescode)
# Out:
# 히죽히
# 눈을 크게 뜨고 웃는 얼굴
# 눈웃음을 치며 웃는 얼굴
# 웃는 눈으로 환한 얼굴
# 히죽히죽 웃는 얼굴
# 땀으로 히죽히죽 웃는 얼굴
# 방바닥에서 뒹굴며 웃기
# 기쁨의 눈물을 흘리다
# 살짝 웃는 얼굴
# 거꾸로 된 얼굴
# ⊛ 녹는 얼굴
# 윙크하는 얼굴
# 눈웃음을 짓고 있는 웃는 얼굴
# 후광으로 웃는 얼굴
# 하트가 있는 웃는 얼굴
# 가슴이 미어지는 듯한 미소.
# 별똥별의
# 키스하는 얼굴
# 키스하는 얼굴
# 웃는얼굴
# 눈을 감고 키스하는 얼굴
# 웃는 눈으로 키스하는 얼굴
# 눈물로 웃는 얼굴
# 음식을 맛보다.
# 혀를 내두르다
# 혀로 얼굴을 찡긋하기
# 익살스러운 얼굴
# 혀로 얼굴을 가늘게 뜨는 것
# 돈 많은 얼굴
# 두 손을 벌리고 웃는 얼굴
# 얼굴을 맞대고 입을 벌리다
# ⊛ 눈을 부릅뜨고 입을 벌린 얼굴
# ⊛ 힐끗 쳐다보다
# 수줍은 얼굴
# 생각하는 얼굴
# ⊛ 경례하는 얼굴
# 얼굴zipper-mouth
# 눈썹을 치켜올린 얼굴
# 중성면
# 무표정한 얼굴
# 구름같이 보이다.
# ⊛ 점선면
# 웃는 얼굴
# 재미없는 얼굴
# 눈알이 돌다
# 찌푸린 얼굴
# 입을 벌리고 마주보다
# 누운 얼굴
# 안심한 얼굴
# 수심에 잠긴 얼굴
# 졸린 얼굴
# 침 흘리는 얼굴
# 잠자는 얼굴
# 의료용 마스크를 쓴 얼굴
# 체온계를 대향하다
# 머리를 싸매다
# 메스꺼운 얼굴
# 구토에 직면하다
# 재채기하는 얼굴
# 화난 얼굴
# 냉담한 얼굴
# 흐릿한 얼굴
# 나선형의 눈을 한 얼굴
# 폭발하는 머리
# 카우보이 모자 얼굴
# 파티하는 얼굴
# 변장한 얼굴
# 선글라스를 낀 웃는 얼굴
# 괴짜 얼굴
# 외눈으로 마주보다
# 혼란스러운 얼굴
# ⊛ 대각선 모양의 입을 가진 얼굴
# 근심스러운 얼굴
# 약간 찌푸린 얼굴
# 찌푸린 얼굴
# 쉰 얼굴
# 놀란 얼굴
# 상기된 얼굴
# 애원하는 얼굴
# ⊛ 눈물을 참는 얼굴
# 입을 벌리고 인상을 찌푸리는 얼굴
# 괴로운 얼굴
# 겁먹은 얼굴
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-c708c303c256> in <module>()
#       5 for i in range(len(emoji)):
#       6     emoji_dict[emoji['Code'][i]] = emoji['CLDR Short Name'][i]
# ----> 7 emoji_dict[3]
#
# KeyError: 3
